# %% [markdown]
# # Import Libraries

# %%
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
import numpy as np
import cv2 
import os
from matplotlib import pyplot as plt
from tensorflow.keras import backend as K
import tqdm.notebook as tq
from tensorflow.keras.layers import Conv2D, MaxPool2D, Conv2DTranspose, Concatenate, Activation, BatchNormalization, Input, GaussianNoise, MaxPooling2D, Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# # Load Pickled Data

# %%
def read_images(img_path, gt_path, SHAPE=(256, 192)):
    images = []
    masks = []
    img_dir = sorted(os.listdir(img_path))
    mask_dir = sorted(os.listdir(gt_path))
    for img in tq.tqdm(img_dir):
        path = os.path.join(img_path, img)
        x = plt.imread(path)
        x = cv2.resize(x, SHAPE)
        images.append(x)
    for mask in tq.tqdm(mask_dir):
        path = os.path.join(gt_path, mask)
        x = plt.imread(path)
        x = cv2.resize(x, SHAPE)
        masks.append(x)
    return np.array(images), np.array(masks)

# %%
import pickle
with open('../input/assign4data/data.txt', 'rb') as fh:
    data=pickle.load(fh)
X=data['x_train']
Y=data['y_train']
X_val=data['x_val']
Y_val=data['y_val']
X_test=data['x_test']
Y_test=data['y_test']
print(X.shape, Y.shape)
print(X_val.shape, Y_val.shape)
print(X_test.shape, Y_test.shape)

# %% [markdown]
# # Data generator function

# %%
def make_data_generators(data_gen_args, data, gt, flow_from_dir_args):
    '''
    Creates the data generators for the pairs of images and the ground truth segmentations
    Function will be modified when we get more understanding of the output
    inputs:
        data_gen_args: dictionary to be initialize the ImageDataGenerator object (see ImageDataGenerator Docs to see options)
        data_path: path for a directory that contains the directory of the images
        gt_path: path for a directory that contains the directory of the ground truths
        flow_from_dir_args: dict to call the flow or flow_from_directory function has target_size, batch_size, class_mode, seed, etc. (see ImageDataGenerator Docs to see options)
    returns:
        generator: a data generator that has can be passed to a model.fit method 
    '''
    image_datagen = ImageDataGenerator(**data_gen_args, rescale=1./255)
    mask_datagen = ImageDataGenerator(**data_gen_args)

    image_generator = image_datagen.flow(data, **flow_from_dir_args)
    mask_generator = mask_datagen.flow(gt[:, :, :, np.newaxis], **flow_from_dir_args)
    
    generator = zip(image_generator, mask_generator)
    
    return generator

# %% [markdown]
# # Make Train and Validation Data generators

# %%
data_gen_args = dict(shear_range=0.2,
                     zoom_range=0.2,
                     rotation_range=90,
                     width_shift_range=0.1,
                     height_shift_range=0.1)
flow_from_dir_args = dict(seed=1, batch_size=16, shuffle=True)

# %%
train_generator = make_data_generators(data_gen_args, X, Y, flow_from_dir_args)
val_generator = make_data_generators(dict(), X_val, Y_val, flow_from_dir_args)

# %% [markdown]
# # Plot Some Images for observation

# %%
def show_images(images, masks, num_images = 5):
    plt.figure(figsize=(15,25))
    axes_num = 0
    for i in range(num_images):
        plt.subplot(num_images, 2, axes_num+1)
        plt.imshow(images[i])
        plt.title('Original Image')

        plt.subplot(num_images, 2, axes_num+2)
        plt.imshow(np.squeeze(masks[i]), cmap='gray')
        plt.title('Segmentation Mask')
        axes_num += 2

    plt.show()

# %%
temp_data = next(train_generator)

# %%
show_images(temp_data[0], temp_data[1])

# %% [markdown]
# # Define Jaccard Coefficient Loss and IOU metric

# %%
def jaccard_loss(y_true, y_pred):
    logits = tf.reshape(y_pred, [-1])
    trn_labels = tf.reshape(y_true, [-1])

    inter = tf.reduce_sum(logits * trn_labels)

    union = tf.reduce_sum((logits + trn_labels) - (logits * trn_labels))

    iou = inter / union
    loss = tf.constant(1.0, dtype=tf.float32) -  (inter/union)
    return loss

# %%
def IOU(y_true, y_pred, th=0.5):
    y_pred[y_pred < th] = 0
    y_pred[y_pred >= th] = 1
    logits = tf.reshape(y_pred, [-1])
    trn_labels = tf.reshape(y_true, [-1])

    inter = tf.reduce_sum(logits * trn_labels)

    union = tf.reduce_sum((logits + trn_labels) - (logits * trn_labels))

    iou = inter/union
    
    return iou

# %% [markdown]
# # Loss and metrics visualization function

# %%
def visualize_loss_and_metric(histories):
    fig , ax = plt.subplots(1,2)
    train_iou = train_loss = test_iou = test_loss = []
    for history in histories:
        train_iou = train_iou + history.history['IOU']
        train_loss = train_loss + history.history['loss']
        test_iou = test_iou + history.history['val_IOU']
        test_loss = test_loss + history.history['val_loss']

    fig.set_size_inches(20,6)
    ax[0].plot(train_loss, label = f'Training Loss')
    ax[0].plot(test_loss , label = f'Validation Loss')
    ax[0].set_title('Training & Validation Loss')
    ax[0].legend()
    ax[0].set_xlabel("Epochs")

    ax[1].plot(train_iou, label = f'Training IOU')
    ax[1].plot(test_iou , label = f'Validation IOU')
    ax[1].set_title('Training & Validation IOU')
    ax[1].legend()
    ax[1].set_xlabel("Epochs")
    plt.show()

# %% [markdown]
# # Unet

# %% [markdown]
# ## Unet Hyperparameters

# %%
UNET_INP_SHAPE = (192, 256, 3)
UNET_LR = 0.003
BATCH_SIZE = 16
EPOCHS = 50

# %% [markdown]
# ## Unet blocks

# %%
def conv_block(inp, num_filters):
    x = Conv2D(num_filters, 3, padding='same', activation='relu')(inp)
    x = Conv2D(num_filters, 3, padding='same', activation='relu')(x)
    x = BatchNormalization()(x)
    return x

def encoder_block(inp, num_filters):
    x = conv_block(inp, num_filters)
    p = MaxPooling2D((2, 2))(x)
    return x, p

def decoder_block(inp, skip_conn, num_filters):
    x = Conv2DTranspose(num_filters, (2, 2), strides=2, padding='same', activation='relu')(inp)
    x = BatchNormalization()(x)
    x = Concatenate()([x, skip_conn])
    x = conv_block(x, num_filters)
    return x

# %% [markdown]
# ## Define Unet model

# %%
def make_unet(input_shape):
    inputs = Input(input_shape)
    s1, p1 = encoder_block(inputs, 64)
    s2, p2 = encoder_block(p1, 128)
    s3, p3 = encoder_block(p2, 256)
    s4, p4 = encoder_block(p3, 512)

    b1 = conv_block(p4, 1024)

    d1 = decoder_block(b1, s4, 512)
    d2 = decoder_block(d1, s3, 256)
    d3 = decoder_block(d2, s2, 128)
    d4 = decoder_block(d3, s1, 64)

    outputs = Conv2D(1, 1, padding='same', activation='sigmoid')(d4)

    model = tf.keras.Model(inputs = [inputs], outputs = [outputs])
    return model

# %%
model = make_unet(UNET_INP_SHAPE)
opt = tf.keras.optimizers.Adam(UNET_LR)
model.compile(loss=jaccard_loss, optimizer=opt, metrics=[IOU])
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 192, 256, 3  0           []
#                                 )]
#
#  conv2d (Conv2D)                (None, 192, 256, 64  1792        ['input_1[0][0]']
#                                 )
#
#  conv2d_1 (Conv2D)              (None, 192, 256, 64  36928       ['conv2d[0][0]']
#                                 )
#
#  batch_normalization (BatchNorm  (None, 192, 256, 64  256        ['conv2d_1[0][0]']
#  alization)                     )
#
#  max_pooling2d (MaxPooling2D)   (None, 96, 128, 64)  0           ['batch_normalization[0][0]']
#
#  conv2d_2 (Conv2D)              (None, 96, 128, 128  73856       ['max_pooling2d[0][0]']
#                                 )
#
#  conv2d_3 (Conv2D)              (None, 96, 128, 128  147584      ['conv2d_2[0][0]']
#                                 )
#
#  batch_normalization_1 (BatchNo  (None, 96, 128, 128  512        ['conv2d_3[0][0]']
#  rmalization)                   )
#
#  max_pooling2d_1 (MaxPooling2D)  (None, 48, 64, 128)  0          ['batch_normalization_1[0][0]']
#
#  conv2d_4 (Conv2D)              (None, 48, 64, 256)  295168      ['max_pooling2d_1[0][0]']
#
#  conv2d_5 (Conv2D)              (None, 48, 64, 256)  590080      ['conv2d_4[0][0]']
#
#  batch_normalization_2 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_5[0][0]']
#  rmalization)
#
#  max_pooling2d_2 (MaxPooling2D)  (None, 24, 32, 256)  0          ['batch_normalization_2[0][0]']
#
#  conv2d_6 (Conv2D)              (None, 24, 32, 512)  1180160     ['max_pooling2d_2[0][0]']
#
#  conv2d_7 (Conv2D)              (None, 24, 32, 512)  2359808     ['conv2d_6[0][0]']
#
#  batch_normalization_3 (BatchNo  (None, 24, 32, 512)  2048       ['conv2d_7[0][0]']
#  rmalization)
#
#  max_pooling2d_3 (MaxPooling2D)  (None, 12, 16, 512)  0          ['batch_normalization_3[0][0]']
#
#  conv2d_8 (Conv2D)              (None, 12, 16, 1024  4719616     ['max_pooling2d_3[0][0]']
#                                 )
#
#  conv2d_9 (Conv2D)              (None, 12, 16, 1024  9438208     ['conv2d_8[0][0]']
#                                 )
#
#  batch_normalization_4 (BatchNo  (None, 12, 16, 1024  4096       ['conv2d_9[0][0]']
#  rmalization)                   )
#
#  conv2d_transpose (Conv2DTransp  (None, 24, 32, 512)  2097664    ['batch_normalization_4[0][0]']
#  ose)
#
#  batch_normalization_5 (BatchNo  (None, 24, 32, 512)  2048       ['conv2d_transpose[0][0]']
#  rmalization)
#
#  concatenate (Concatenate)      (None, 24, 32, 1024  0           ['batch_normalization_5[0][0]',
#                                 )                                 'batch_normalization_3[0][0]']
#
#  conv2d_10 (Conv2D)             (None, 24, 32, 512)  4719104     ['concatenate[0][0]']
#
#  conv2d_11 (Conv2D)             (None, 24, 32, 512)  2359808     ['conv2d_10[0][0]']
#
#  batch_normalization_6 (BatchNo  (None, 24, 32, 512)  2048       ['conv2d_11[0][0]']
#  rmalization)
#
#  conv2d_transpose_1 (Conv2DTran  (None, 48, 64, 256)  524544     ['batch_normalization_6[0][0]']
#  spose)
#
#  batch_normalization_7 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_transpose_1[0][0]']
#  rmalization)
#
#  concatenate_1 (Concatenate)    (None, 48, 64, 512)  0           ['batch_normalization_7[0][0]',
#                                                                   'batch_normalization_2[0][0]']
#
#  conv2d_12 (Conv2D)             (None, 48, 64, 256)  1179904     ['concatenate_1[0][0]']
#
#  conv2d_13 (Conv2D)             (None, 48, 64, 256)  590080      ['conv2d_12[0][0]']
#
#  batch_normalization_8 (BatchNo  (None, 48, 64, 256)  1024       ['conv2d_13[0][0]']
#  rmalization)
#
#  conv2d_transpose_2 (Conv2DTran  (None, 96, 128, 128  131200     ['batch_normalization_8[0][0]']
#  spose)                         )
#
#  batch_normalization_9 (BatchNo  (None, 96, 128, 128  512        ['conv2d_transpose_2[0][0]']
#  rmalization)                   )
#
#  concatenate_2 (Concatenate)    (None, 96, 128, 256  0           ['batch_normalization_9[0][0]',
#                                 )                                 'batch_normalization_1[0][0]']
#
#  conv2d_14 (Conv2D)             (None, 96, 128, 128  295040      ['concatenate_2[0][0]']
#                                 )
#
#  conv2d_15 (Conv2D)             (None, 96, 128, 128  147584      ['conv2d_14[0][0]']
#                                 )
#
#  batch_normalization_10 (BatchN  (None, 96, 128, 128  512        ['conv2d_15[0][0]']
#  ormalization)                  )
#
#  conv2d_transpose_3 (Conv2DTran  (None, 192, 256, 64  32832      ['batch_normalization_10[0][0]']
#  spose)                         )
#
#  batch_normalization_11 (BatchN  (None, 192, 256, 64  256        ['conv2d_transpose_3[0][0]']
#  ormalization)                  )
#
#  concatenate_3 (Concatenate)    (None, 192, 256, 12  0           ['batch_normalization_11[0][0]',
#                                 8)                                'batch_normalization[0][0]']
#
#  conv2d_16 (Conv2D)             (None, 192, 256, 64  73792       ['concatenate_3[0][0]']
#                                 )
#
#  conv2d_17 (Conv2D)             (None, 192, 256, 64  36928       ['conv2d_16[0][0]']
#                                 )
#
#  batch_normalization_12 (BatchN  (None, 192, 256, 64  256        ['conv2d_17[0][0]']
#  ormalization)                  )
#
#  conv2d_18 (Conv2D)             (None, 192, 256, 1)  65          ['batch_normalization_12[0][0]']
#
# ==================================================================================================
# Total params: 31,047,361
# Trainable params: 31,039,553
# Non-trainable params: 7,808
# __________________________________________________________________________________________________

# %% [markdown]
# ### Plot Model

# %%
tf.keras.utils.plot_model(model)

# %% [markdown]
# ## Train Unet

# %%
steps_per_epoch_train = 2000 // BATCH_SIZE
steps_per_epoch_val = 150 // BATCH_SIZE

# %%
lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=0.0003)

# %%
history2 = model.fit(train_generator, 
                    steps_per_epoch=steps_per_epoch_train,
                    epochs=20,
                    validation_data=val_generator, 
                    validation_steps=steps_per_epoch_val,
                    callbacks=[lr_reduce])
# Out:
# Epoch 1/20
# 125/125 [==============================] - 42s 336ms/step - loss: 0.1992 - IOU: 0.8008 - val_loss: 0.3622 - val_IOU: 0.6378
# Epoch 2/20
# 125/125 [==============================] - 42s 336ms/step - loss: 0.1934 - IOU: 0.8066 - val_loss: 0.3305 - val_IOU: 0.6695
# Epoch 3/20
# 125/125 [==============================] - 41s 332ms/step - loss: 0.1824 - IOU: 0.8176 - val_loss: 0.3963 - val_IOU: 0.6037
# Epoch 4/20
# 125/125 [==============================] - 42s 337ms/step - loss: 0.1948 - IOU: 0.8052 - val_loss: 0.3249 - val_IOU: 0.6751
# Epoch 5/20
# 125/125 [==============================] - 42s 333ms/step - loss: 0.1877 - IOU: 0.8123 - val_loss: 0.3470 - val_IOU: 0.6530
# Epoch 6/20
# 125/125 [==============================] - 42s 334ms/step - loss: 0.1900 - IOU: 0.8100 - val_loss: 0.3339 - val_IOU: 0.6661
# Epoch 7/20
# 125/125 [==============================] - 42s 333ms/step - loss: 0.1857 - IOU: 0.8143 - val_loss: 0.3493 - val_IOU: 0.6507
# Epoch 8/20
# 125/125 [==============================] - 42s 338ms/step - loss: 0.1937 - IOU: 0.8063 - val_loss: 0.3769 - val_IOU: 0.6231
# Epoch 9/20
# 125/125 [==============================] - 42s 336ms/step - loss: 0.1981 - IOU: 0.8019 - val_loss: 0.3303 - val_IOU: 0.6697
#
# Epoch 00009: ReduceLROnPlateau reducing learning rate to 0.001500000013038516.
# Epoch 10/20
# 125/125 [==============================] - 41s 331ms/step - loss: 0.1930 - IOU: 0.8070 - val_loss: 0.3224 - val_IOU: 0.6776
# Epoch 11/20
# 125/125 [==============================] - 42s 334ms/step - loss: 0.1770 - IOU: 0.8230 - val_loss: 0.2881 - val_IOU: 0.7119
# Epoch 12/20
# 125/125 [==============================] - 42s 334ms/step - loss: 0.1786 - IOU: 0.8214 - val_loss: 0.3271 - val_IOU: 0.6729
# Epoch 13/20
# 125/125 [==============================] - 42s 334ms/step - loss: 0.1760 - IOU: 0.8240 - val_loss: 0.2965 - val_IOU: 0.7035
# Epoch 14/20
# 125/125 [==============================] - 42s 336ms/step - loss: 0.1795 - IOU: 0.8205 - val_loss: 0.3083 - val_IOU: 0.6917
# Epoch 15/20
# 125/125 [==============================] - 42s 335ms/step - loss: 0.1744 - IOU: 0.8256 - val_loss: 0.2995 - val_IOU: 0.7005
# Epoch 16/20
# 125/125 [==============================] - 42s 335ms/step - loss: 0.1764 - IOU: 0.8236 - val_loss: 0.3154 - val_IOU: 0.6846
#
# Epoch 00016: ReduceLROnPlateau reducing learning rate to 0.000750000006519258.
# Epoch 17/20
# 125/125 [==============================] - 42s 333ms/step - loss: 0.1801 - IOU: 0.8199 - val_loss: 0.3000 - val_IOU: 0.7000
# Epoch 18/20
# 125/125 [==============================] - 42s 336ms/step - loss: 0.1666 - IOU: 0.8334 - val_loss: 0.3064 - val_IOU: 0.6936
# Epoch 19/20
# 125/125 [==============================] - 42s 337ms/step - loss: 0.1699 - IOU: 0.8301 - val_loss: 0.2851 - val_IOU: 0.7149
# Epoch 20/20
# 125/125 [==============================] - 41s 331ms/step - loss: 0.1690 - IOU: 0.8310 - val_loss: 0.2669 - val_IOU: 0.7331

# %% [markdown]
# ## Unet Trials

# %% [markdown]
# ### Model with starting LR = 0.01 for 70 epochs

# %%
visualize_loss_and_metric([history, history1])

# %% [markdown]
# ### Model with starting LR = 0.001 for 70 epochs

# %%
visualize_loss_and_metric([history1, history2])

# %% [markdown]
# ### Model with starting LR = 0.003 for 70 epochs

# %%
visualize_loss_and_metric([history, history1])

# %%
out = model.predict(X_test * (1./255), batch_size=16)
out.shape
# Out:
# (600, 192, 256, 1)

# %%
iou = IOU(Y_test, out)
print(iou)
# Out:
# tf.Tensor(0.7186657, shape=(), dtype=float32)

# %% [markdown]
# ## Results on test set for best model

# %%
axes_num = 0
num_images = 10
index_list = np.random.choice(600, num_images)
for i in range(num_images):
    plt.figure(figsize=(15,25))
    plt.subplot(num_images, 3, axes_num+1)
    plt.imshow(X_test[index_list[i]])
    plt.title('Original Image')

    plt.subplot(num_images, 3, axes_num+2)
    plt.imshow(np.squeeze(out[index_list[i]]), cmap='gray')
    plt.title('Predicted Segmentation')
    
    plt.subplot(num_images, 3, axes_num+3)
    plt.imshow(np.squeeze(Y_test[index_list[i]]), cmap='gray')
    plt.title('GroundTruth Segmentation')
    axes_num += 3

plt.show()

# %%
model.save_weights('unet_w.h5')

# %% [markdown]
# ## Resnet V2 as a pretrained encoder for Unet
# imagenet weights as an initializer
#
# LR = 0.0003
#
# 75 epochs
#
# 40 million params

# %%
def build_ResNetV2_unet(input_shape):
    """ Input """
    inputs = Input(input_shape)

    res = tf.keras.applications.resnet_v2.ResNet50V2(include_top=False,input_tensor=inputs)
    
    """ Encoder """
    s1 = res.get_layer("conv1_conv").output
    s2 = res.get_layer("conv2_block2_out").output         
    s3 = res.get_layer("conv3_block3_out").output         
    s4 = res.get_layer("conv4_block5_out").output        

    
    b1 = res.get_layer("post_relu").output         

    
    d1 = decoder_block(b1, s4, 512)                    
    d2 = decoder_block(d1, s3, 256)                    
    d3 = decoder_block(d2, s2, 128)                    
    d4 = decoder_block(d3, s1, 64)                     
    x = Conv2DTranspose(32, (2, 2), strides=2, padding='same', activation='relu')(d4)
#    
    outputs = Conv2D(1, 1, padding="same", activation="sigmoid")(x)

    model = Model(inputs, outputs, name="RES_U-Net")
    return model

# %%
input_shape = (192, 256, 3)
model = build_ResNetV2_unet(input_shape)
opt = tf.keras.optimizers.Adam(0.0003)
# model.load_weights('best/unet_weights.h5')
model.compile(loss=jaccard_loss, optimizer=opt, metrics=[IOU])
model.summary()
# Out:
# Model: "RES_U-Net"
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_2 (InputLayer)            [(None, 192, 256, 3) 0
# __________________________________________________________________________________________________
# conv1_pad (ZeroPadding2D)       (None, 198, 262, 3)  0           input_2[0][0]
# __________________________________________________________________________________________________
# conv1_conv (Conv2D)             (None, 96, 128, 64)  9472        conv1_pad[0][0]
# __________________________________________________________________________________________________
# pool1_pad (ZeroPadding2D)       (None, 98, 130, 64)  0           conv1_conv[0][0]
# __________________________________________________________________________________________________
# pool1_pool (MaxPooling2D)       (None, 48, 64, 64)   0           pool1_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_bn (BatchNo (None, 48, 64, 64)   256         pool1_pool[0][0]
# __________________________________________________________________________________________________
# conv2_block1_preact_relu (Activ (None, 48, 64, 64)   0           conv2_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_conv (Conv2D)    (None, 48, 64, 64)   4096        conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_bn (BatchNormali (None, 48, 64, 64)   256         conv2_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_1_relu (Activation (None, 48, 64, 64)   0           conv2_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_pad (ZeroPadding (None, 50, 66, 64)   0           conv2_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_conv (Conv2D)    (None, 48, 64, 64)   36864       conv2_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_bn (BatchNormali (None, 48, 64, 64)   256         conv2_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block1_2_relu (Activation (None, 48, 64, 64)   0           conv2_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block1_0_conv (Conv2D)    (None, 48, 64, 256)  16640       conv2_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_3_conv (Conv2D)    (None, 48, 64, 256)  16640       conv2_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block1_out (Add)          (None, 48, 64, 256)  0           conv2_block1_0_conv[0][0]
#                                                                  conv2_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_bn (BatchNo (None, 48, 64, 256)  1024        conv2_block1_out[0][0]
# __________________________________________________________________________________________________
# conv2_block2_preact_relu (Activ (None, 48, 64, 256)  0           conv2_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_conv (Conv2D)    (None, 48, 64, 64)   16384       conv2_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_bn (BatchNormali (None, 48, 64, 64)   256         conv2_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_1_relu (Activation (None, 48, 64, 64)   0           conv2_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_pad (ZeroPadding (None, 50, 66, 64)   0           conv2_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_conv (Conv2D)    (None, 48, 64, 64)   36864       conv2_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_bn (BatchNormali (None, 48, 64, 64)   256         conv2_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block2_2_relu (Activation (None, 48, 64, 64)   0           conv2_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block2_3_conv (Conv2D)    (None, 48, 64, 256)  16640       conv2_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block2_out (Add)          (None, 48, 64, 256)  0           conv2_block1_out[0][0]
#                                                                  conv2_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_bn (BatchNo (None, 48, 64, 256)  1024        conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_preact_relu (Activ (None, 48, 64, 256)  0           conv2_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_conv (Conv2D)    (None, 48, 64, 64)   16384       conv2_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_bn (BatchNormali (None, 48, 64, 64)   256         conv2_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_1_relu (Activation (None, 48, 64, 64)   0           conv2_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_pad (ZeroPadding (None, 50, 66, 64)   0           conv2_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_conv (Conv2D)    (None, 24, 32, 64)   36864       conv2_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_bn (BatchNormali (None, 24, 32, 64)   256         conv2_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv2_block3_2_relu (Activation (None, 24, 32, 64)   0           conv2_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, 24, 32, 256)  0           conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2_block3_3_conv (Conv2D)    (None, 24, 32, 256)  16640       conv2_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv2_block3_out (Add)          (None, 24, 32, 256)  0           max_pooling2d_3[0][0]
#                                                                  conv2_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_bn (BatchNo (None, 24, 32, 256)  1024        conv2_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block1_preact_relu (Activ (None, 24, 32, 256)  0           conv3_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_conv (Conv2D)    (None, 24, 32, 128)  32768       conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_1_relu (Activation (None, 24, 32, 128)  0           conv3_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_pad (ZeroPadding (None, 26, 34, 128)  0           conv3_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_conv (Conv2D)    (None, 24, 32, 128)  147456      conv3_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block1_2_relu (Activation (None, 24, 32, 128)  0           conv3_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block1_0_conv (Conv2D)    (None, 24, 32, 512)  131584      conv3_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_3_conv (Conv2D)    (None, 24, 32, 512)  66048       conv3_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block1_out (Add)          (None, 24, 32, 512)  0           conv3_block1_0_conv[0][0]
#                                                                  conv3_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_bn (BatchNo (None, 24, 32, 512)  2048        conv3_block1_out[0][0]
# __________________________________________________________________________________________________
# conv3_block2_preact_relu (Activ (None, 24, 32, 512)  0           conv3_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_conv (Conv2D)    (None, 24, 32, 128)  65536       conv3_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_1_relu (Activation (None, 24, 32, 128)  0           conv3_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_pad (ZeroPadding (None, 26, 34, 128)  0           conv3_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_conv (Conv2D)    (None, 24, 32, 128)  147456      conv3_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block2_2_relu (Activation (None, 24, 32, 128)  0           conv3_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block2_3_conv (Conv2D)    (None, 24, 32, 512)  66048       conv3_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block2_out (Add)          (None, 24, 32, 512)  0           conv3_block1_out[0][0]
#                                                                  conv3_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_bn (BatchNo (None, 24, 32, 512)  2048        conv3_block2_out[0][0]
# __________________________________________________________________________________________________
# conv3_block3_preact_relu (Activ (None, 24, 32, 512)  0           conv3_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_conv (Conv2D)    (None, 24, 32, 128)  65536       conv3_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_1_relu (Activation (None, 24, 32, 128)  0           conv3_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_pad (ZeroPadding (None, 26, 34, 128)  0           conv3_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_conv (Conv2D)    (None, 24, 32, 128)  147456      conv3_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block3_2_relu (Activation (None, 24, 32, 128)  0           conv3_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block3_3_conv (Conv2D)    (None, 24, 32, 512)  66048       conv3_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block3_out (Add)          (None, 24, 32, 512)  0           conv3_block2_out[0][0]
#                                                                  conv3_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_bn (BatchNo (None, 24, 32, 512)  2048        conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_preact_relu (Activ (None, 24, 32, 512)  0           conv3_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_conv (Conv2D)    (None, 24, 32, 128)  65536       conv3_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_bn (BatchNormali (None, 24, 32, 128)  512         conv3_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_1_relu (Activation (None, 24, 32, 128)  0           conv3_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_pad (ZeroPadding (None, 26, 34, 128)  0           conv3_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_conv (Conv2D)    (None, 12, 16, 128)  147456      conv3_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_bn (BatchNormali (None, 12, 16, 128)  512         conv3_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv3_block4_2_relu (Activation (None, 12, 16, 128)  0           conv3_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, 12, 16, 512)  0           conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv3_block4_3_conv (Conv2D)    (None, 12, 16, 512)  66048       conv3_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv3_block4_out (Add)          (None, 12, 16, 512)  0           max_pooling2d_4[0][0]
#                                                                  conv3_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_bn (BatchNo (None, 12, 16, 512)  2048        conv3_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block1_preact_relu (Activ (None, 12, 16, 512)  0           conv4_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_conv (Conv2D)    (None, 12, 16, 256)  131072      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_1_relu (Activation (None, 12, 16, 256)  0           conv4_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_conv (Conv2D)    (None, 12, 16, 256)  589824      conv4_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block1_2_relu (Activation (None, 12, 16, 256)  0           conv4_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block1_0_conv (Conv2D)    (None, 12, 16, 1024) 525312      conv4_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_3_conv (Conv2D)    (None, 12, 16, 1024) 263168      conv4_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block1_out (Add)          (None, 12, 16, 1024) 0           conv4_block1_0_conv[0][0]
#                                                                  conv4_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_bn (BatchNo (None, 12, 16, 1024) 4096        conv4_block1_out[0][0]
# __________________________________________________________________________________________________
# conv4_block2_preact_relu (Activ (None, 12, 16, 1024) 0           conv4_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_conv (Conv2D)    (None, 12, 16, 256)  262144      conv4_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_1_relu (Activation (None, 12, 16, 256)  0           conv4_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_conv (Conv2D)    (None, 12, 16, 256)  589824      conv4_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block2_2_relu (Activation (None, 12, 16, 256)  0           conv4_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block2_3_conv (Conv2D)    (None, 12, 16, 1024) 263168      conv4_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block2_out (Add)          (None, 12, 16, 1024) 0           conv4_block1_out[0][0]
#                                                                  conv4_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_bn (BatchNo (None, 12, 16, 1024) 4096        conv4_block2_out[0][0]
# __________________________________________________________________________________________________
# conv4_block3_preact_relu (Activ (None, 12, 16, 1024) 0           conv4_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_conv (Conv2D)    (None, 12, 16, 256)  262144      conv4_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_1_relu (Activation (None, 12, 16, 256)  0           conv4_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_conv (Conv2D)    (None, 12, 16, 256)  589824      conv4_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block3_2_relu (Activation (None, 12, 16, 256)  0           conv4_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block3_3_conv (Conv2D)    (None, 12, 16, 1024) 263168      conv4_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block3_out (Add)          (None, 12, 16, 1024) 0           conv4_block2_out[0][0]
#                                                                  conv4_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_bn (BatchNo (None, 12, 16, 1024) 4096        conv4_block3_out[0][0]
# __________________________________________________________________________________________________
# conv4_block4_preact_relu (Activ (None, 12, 16, 1024) 0           conv4_block4_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_conv (Conv2D)    (None, 12, 16, 256)  262144      conv4_block4_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block4_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_1_relu (Activation (None, 12, 16, 256)  0           conv4_block4_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block4_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_conv (Conv2D)    (None, 12, 16, 256)  589824      conv4_block4_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block4_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block4_2_relu (Activation (None, 12, 16, 256)  0           conv4_block4_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block4_3_conv (Conv2D)    (None, 12, 16, 1024) 263168      conv4_block4_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block4_out (Add)          (None, 12, 16, 1024) 0           conv4_block3_out[0][0]
#                                                                  conv4_block4_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_bn (BatchNo (None, 12, 16, 1024) 4096        conv4_block4_out[0][0]
# __________________________________________________________________________________________________
# conv4_block5_preact_relu (Activ (None, 12, 16, 1024) 0           conv4_block5_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_conv (Conv2D)    (None, 12, 16, 256)  262144      conv4_block5_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block5_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_1_relu (Activation (None, 12, 16, 256)  0           conv4_block5_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block5_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_conv (Conv2D)    (None, 12, 16, 256)  589824      conv4_block5_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block5_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block5_2_relu (Activation (None, 12, 16, 256)  0           conv4_block5_2_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block5_3_conv (Conv2D)    (None, 12, 16, 1024) 263168      conv4_block5_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block5_out (Add)          (None, 12, 16, 1024) 0           conv4_block4_out[0][0]
#                                                                  conv4_block5_3_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_bn (BatchNo (None, 12, 16, 1024) 4096        conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_preact_relu (Activ (None, 12, 16, 1024) 0           conv4_block6_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_conv (Conv2D)    (None, 12, 16, 256)  262144      conv4_block6_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_bn (BatchNormali (None, 12, 16, 256)  1024        conv4_block6_1_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_1_relu (Activation (None, 12, 16, 256)  0           conv4_block6_1_bn[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_pad (ZeroPadding (None, 14, 18, 256)  0           conv4_block6_1_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_conv (Conv2D)    (None, 6, 8, 256)    589824      conv4_block6_2_pad[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_bn (BatchNormali (None, 6, 8, 256)    1024        conv4_block6_2_conv[0][0]
# __________________________________________________________________________________________________
# conv4_block6_2_relu (Activation (None, 6, 8, 256)    0           conv4_block6_2_bn[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_5 (MaxPooling2D)  (None, 6, 8, 1024)   0           conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv4_block6_3_conv (Conv2D)    (None, 6, 8, 1024)   263168      conv4_block6_2_relu[0][0]
# __________________________________________________________________________________________________
# conv4_block6_out (Add)          (None, 6, 8, 1024)   0           max_pooling2d_5[0][0]
#                                                                  conv4_block6_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_bn (BatchNo (None, 6, 8, 1024)   4096        conv4_block6_out[0][0]
# __________________________________________________________________________________________________
# conv5_block1_preact_relu (Activ (None, 6, 8, 1024)   0           conv5_block1_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_conv (Conv2D)    (None, 6, 8, 512)    524288      conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block1_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_1_relu (Activation (None, 6, 8, 512)    0           conv5_block1_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_pad (ZeroPadding (None, 8, 10, 512)   0           conv5_block1_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_conv (Conv2D)    (None, 6, 8, 512)    2359296     conv5_block1_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block1_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block1_2_relu (Activation (None, 6, 8, 512)    0           conv5_block1_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block1_0_conv (Conv2D)    (None, 6, 8, 2048)   2099200     conv5_block1_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_3_conv (Conv2D)    (None, 6, 8, 2048)   1050624     conv5_block1_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block1_out (Add)          (None, 6, 8, 2048)   0           conv5_block1_0_conv[0][0]
#                                                                  conv5_block1_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_bn (BatchNo (None, 6, 8, 2048)   8192        conv5_block1_out[0][0]
# __________________________________________________________________________________________________
# conv5_block2_preact_relu (Activ (None, 6, 8, 2048)   0           conv5_block2_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_conv (Conv2D)    (None, 6, 8, 512)    1048576     conv5_block2_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block2_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_1_relu (Activation (None, 6, 8, 512)    0           conv5_block2_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_pad (ZeroPadding (None, 8, 10, 512)   0           conv5_block2_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_conv (Conv2D)    (None, 6, 8, 512)    2359296     conv5_block2_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block2_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block2_2_relu (Activation (None, 6, 8, 512)    0           conv5_block2_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block2_3_conv (Conv2D)    (None, 6, 8, 2048)   1050624     conv5_block2_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block2_out (Add)          (None, 6, 8, 2048)   0           conv5_block1_out[0][0]
#                                                                  conv5_block2_3_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_bn (BatchNo (None, 6, 8, 2048)   8192        conv5_block2_out[0][0]
# __________________________________________________________________________________________________
# conv5_block3_preact_relu (Activ (None, 6, 8, 2048)   0           conv5_block3_preact_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_conv (Conv2D)    (None, 6, 8, 512)    1048576     conv5_block3_preact_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block3_1_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_1_relu (Activation (None, 6, 8, 512)    0           conv5_block3_1_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_pad (ZeroPadding (None, 8, 10, 512)   0           conv5_block3_1_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_conv (Conv2D)    (None, 6, 8, 512)    2359296     conv5_block3_2_pad[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_bn (BatchNormali (None, 6, 8, 512)    2048        conv5_block3_2_conv[0][0]
# __________________________________________________________________________________________________
# conv5_block3_2_relu (Activation (None, 6, 8, 512)    0           conv5_block3_2_bn[0][0]
# __________________________________________________________________________________________________
# conv5_block3_3_conv (Conv2D)    (None, 6, 8, 2048)   1050624     conv5_block3_2_relu[0][0]
# __________________________________________________________________________________________________
# conv5_block3_out (Add)          (None, 6, 8, 2048)   0           conv5_block2_out[0][0]
#                                                                  conv5_block3_3_conv[0][0]
# __________________________________________________________________________________________________
# post_bn (BatchNormalization)    (None, 6, 8, 2048)   8192        conv5_block3_out[0][0]
# __________________________________________________________________________________________________
# post_relu (Activation)          (None, 6, 8, 2048)   0           post_bn[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_5 (Conv2DTrans (None, 12, 16, 512)  4194816     post_relu[0][0]
# __________________________________________________________________________________________________
# batch_normalization_8 (BatchNor (None, 12, 16, 512)  2048        conv2d_transpose_5[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, 12, 16, 1536) 0           batch_normalization_8[0][0]
#                                                                  conv4_block5_out[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, 12, 16, 512)  7078400     concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, 12, 16, 512)  2359808     conv2d_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_9 (BatchNor (None, 12, 16, 512)  2048        conv2d_10[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_6 (Conv2DTrans (None, 24, 32, 256)  524544      batch_normalization_9[0][0]
# __________________________________________________________________________________________________
# batch_normalization_10 (BatchNo (None, 24, 32, 256)  1024        conv2d_transpose_6[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, 24, 32, 768)  0           batch_normalization_10[0][0]
#                                                                  conv3_block3_out[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, 24, 32, 256)  1769728     concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, 24, 32, 256)  590080      conv2d_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_11 (BatchNo (None, 24, 32, 256)  1024        conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_7 (Conv2DTrans (None, 48, 64, 128)  131200      batch_normalization_11[0][0]
# __________________________________________________________________________________________________
# batch_normalization_12 (BatchNo (None, 48, 64, 128)  512         conv2d_transpose_7[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, 48, 64, 384)  0           batch_normalization_12[0][0]
#                                                                  conv2_block2_out[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, 48, 64, 128)  442496      concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, 48, 64, 128)  147584      conv2d_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_13 (BatchNo (None, 48, 64, 128)  512         conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_8 (Conv2DTrans (None, 96, 128, 64)  32832       batch_normalization_13[0][0]
# __________________________________________________________________________________________________
# batch_normalization_14 (BatchNo (None, 96, 128, 64)  256         conv2d_transpose_8[0][0]
# __________________________________________________________________________________________________
# concatenate_7 (Concatenate)     (None, 96, 128, 128) 0           batch_normalization_14[0][0]
#                                                                  conv1_conv[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, 96, 128, 64)  73792       concatenate_7[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, 96, 128, 64)  36928       conv2d_15[0][0]
# __________________________________________________________________________________________________
# batch_normalization_15 (BatchNo (None, 96, 128, 64)  256         conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_transpose_9 (Conv2DTrans (None, 192, 256, 32) 8224        batch_normalization_15[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, 192, 256, 1)  33          conv2d_transpose_9[0][0]
# ==================================================================================================
# Total params: 40,962,945
# Trainable params: 40,913,665
# Non-trainable params: 49,280
# __________________________________________________________________________________________________

# %%
steps_per_epoch_train = 2000 // 16
steps_per_epoch_val = 150 // 16

# %%
os.mkdir('best')

# %%
lr_reduce = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_loss', factor=0.5, patience=5, verbose=1, min_lr=0.00003)
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint(
    filepath='./best/unet_weights.h5',
    save_weights_only=True,
    monitor='val_loss',
    save_best_only=True,
    verbose=1
)

# %%
history1 = model.fit(train_generator, 
                    steps_per_epoch=steps_per_epoch_train,
                    epochs=75,
                    validation_data=val_generator,
                    validation_steps=steps_per_epoch_val,
                    callbacks=[lr_reduce, model_checkpoint_callback]
                   )
# Out:
# 2022-01-21 09:50:31.288223: I tensorflow/compiler/mlir/mlir_graph_optimization_pass.cc:185] None of the MLIR Optimization Passes are enabled (registered 2)
# Epoch 1/75
# 2022-01-21 09:50:37.613649: I tensorflow/stream_executor/cuda/cuda_dnn.cc:369] Loaded cuDNN version 8005
# 125/125 [==============================] - 48s 278ms/step - loss: 0.4056 - IOU: 0.5944 - val_loss: 0.7651 - val_IOU: 0.2349
#
# Epoch 00001: val_loss improved from inf to 0.76513, saving model to ./best/unet_weights.h5
# Epoch 2/75
# 125/125 [==============================] - 34s 274ms/step - loss: 0.2430 - IOU: 0.7570 - val_loss: 0.4007 - val_IOU: 0.5993
#
# Epoch 00002: val_loss improved from 0.76513 to 0.40066, saving model to ./best/unet_weights.h5
# Epoch 3/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.2332 - IOU: 0.7668 - val_loss: 0.5727 - val_IOU: 0.4273
#
# Epoch 00003: val_loss did not improve from 0.40066
# Epoch 4/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.2203 - IOU: 0.7797 - val_loss: 0.3913 - val_IOU: 0.6087
#
# Epoch 00004: val_loss improved from 0.40066 to 0.39132, saving model to ./best/unet_weights.h5
# Epoch 5/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.2087 - IOU: 0.7913 - val_loss: 0.3224 - val_IOU: 0.6776
#
# Epoch 00005: val_loss improved from 0.39132 to 0.32242, saving model to ./best/unet_weights.h5
# Epoch 6/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.2126 - IOU: 0.7874 - val_loss: 0.3325 - val_IOU: 0.6675
#
# Epoch 00006: val_loss did not improve from 0.32242
# Epoch 7/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.2053 - IOU: 0.7947 - val_loss: 0.5806 - val_IOU: 0.4194
#
# Epoch 00007: val_loss did not improve from 0.32242
# Epoch 8/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1928 - IOU: 0.8072 - val_loss: 0.4509 - val_IOU: 0.5491
#
# Epoch 00008: val_loss did not improve from 0.32242
# Epoch 9/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1916 - IOU: 0.8084 - val_loss: 0.3312 - val_IOU: 0.6688
#
# Epoch 00009: val_loss did not improve from 0.32242
# Epoch 10/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1960 - IOU: 0.8040 - val_loss: 0.3393 - val_IOU: 0.6607
#
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 0.0001500000071246177.
#
# Epoch 00010: val_loss did not improve from 0.32242
# Epoch 11/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1777 - IOU: 0.8223 - val_loss: 0.3165 - val_IOU: 0.6835
#
# Epoch 00011: val_loss improved from 0.32242 to 0.31652, saving model to ./best/unet_weights.h5
# Epoch 12/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1767 - IOU: 0.8233 - val_loss: 0.3136 - val_IOU: 0.6864
#
# Epoch 00012: val_loss improved from 0.31652 to 0.31362, saving model to ./best/unet_weights.h5
# Epoch 13/75
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1683 - IOU: 0.8317 - val_loss: 0.3117 - val_IOU: 0.6883
#
# Epoch 00013: val_loss improved from 0.31362 to 0.31173, saving model to ./best/unet_weights.h5
# Epoch 14/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1656 - IOU: 0.8344 - val_loss: 0.3029 - val_IOU: 0.6971
#
# Epoch 00014: val_loss improved from 0.31173 to 0.30290, saving model to ./best/unet_weights.h5
# Epoch 15/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1659 - IOU: 0.8341 - val_loss: 0.3233 - val_IOU: 0.6767
#
# Epoch 00015: val_loss did not improve from 0.30290
# Epoch 16/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1603 - IOU: 0.8397 - val_loss: 0.2660 - val_IOU: 0.7340
#
# Epoch 00016: val_loss improved from 0.30290 to 0.26602, saving model to ./best/unet_weights.h5
# Epoch 17/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1624 - IOU: 0.8376 - val_loss: 0.3051 - val_IOU: 0.6949
#
# Epoch 00017: val_loss did not improve from 0.26602
# Epoch 18/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1667 - IOU: 0.8333 - val_loss: 0.2990 - val_IOU: 0.7010
#
# Epoch 00018: val_loss did not improve from 0.26602
# Epoch 19/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1618 - IOU: 0.8382 - val_loss: 0.3191 - val_IOU: 0.6809
#
# Epoch 00019: val_loss did not improve from 0.26602
# Epoch 20/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1558 - IOU: 0.8442 - val_loss: 0.4430 - val_IOU: 0.5570
#
# Epoch 00020: val_loss did not improve from 0.26602
# Epoch 21/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1574 - IOU: 0.8426 - val_loss: 0.3022 - val_IOU: 0.6978
#
# Epoch 00021: ReduceLROnPlateau reducing learning rate to 7.500000356230885e-05.
#
# Epoch 00021: val_loss did not improve from 0.26602
# Epoch 22/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1503 - IOU: 0.8497 - val_loss: 0.2864 - val_IOU: 0.7136
#
# Epoch 00022: val_loss did not improve from 0.26602
# Epoch 23/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.6591 - IOU: 0.3409 - val_loss: 0.4959 - val_IOU: 0.5041
#
# Epoch 00023: val_loss did not improve from 0.26602
# Epoch 24/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1726 - IOU: 0.8274 - val_loss: 0.3064 - val_IOU: 0.6936
#
# Epoch 00024: val_loss did not improve from 0.26602
# Epoch 25/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1481 - IOU: 0.8519 - val_loss: 0.2504 - val_IOU: 0.7496
#
# Epoch 00025: val_loss improved from 0.26602 to 0.25040, saving model to ./best/unet_weights.h5
# Epoch 26/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1474 - IOU: 0.8526 - val_loss: 0.3226 - val_IOU: 0.6774
#
# Epoch 00026: val_loss did not improve from 0.25040
# Epoch 27/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1511 - IOU: 0.8489 - val_loss: 0.3058 - val_IOU: 0.6942
#
# Epoch 00027: val_loss did not improve from 0.25040
# Epoch 28/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1489 - IOU: 0.8511 - val_loss: 0.2752 - val_IOU: 0.7248
#
# Epoch 00028: val_loss did not improve from 0.25040
# Epoch 29/75
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1445 - IOU: 0.8555 - val_loss: 0.2945 - val_IOU: 0.7055
#
# Epoch 00029: val_loss did not improve from 0.25040
# Epoch 30/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1430 - IOU: 0.8570 - val_loss: 0.3081 - val_IOU: 0.6919
#
# Epoch 00030: ReduceLROnPlateau reducing learning rate to 3.7500001781154424e-05.
#
# Epoch 00030: val_loss did not improve from 0.25040
# Epoch 31/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1397 - IOU: 0.8603 - val_loss: 0.2695 - val_IOU: 0.7305
#
# Epoch 00031: val_loss did not improve from 0.25040
# Epoch 32/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1389 - IOU: 0.8611 - val_loss: 0.2763 - val_IOU: 0.7237
#
# Epoch 00032: val_loss did not improve from 0.25040
# Epoch 33/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1398 - IOU: 0.8602 - val_loss: 0.3002 - val_IOU: 0.6998
#
# Epoch 00033: val_loss did not improve from 0.25040
# Epoch 34/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1381 - IOU: 0.8619 - val_loss: 0.2813 - val_IOU: 0.7187
#
# Epoch 00034: val_loss did not improve from 0.25040
# Epoch 35/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1368 - IOU: 0.8632 - val_loss: 0.2729 - val_IOU: 0.7271
#
# Epoch 00035: ReduceLROnPlateau reducing learning rate to 3e-05.
#
# Epoch 00035: val_loss did not improve from 0.25040
# Epoch 36/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1336 - IOU: 0.8664 - val_loss: 0.2493 - val_IOU: 0.7507
#
# Epoch 00036: val_loss improved from 0.25040 to 0.24932, saving model to ./best/unet_weights.h5
# Epoch 37/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1338 - IOU: 0.8662 - val_loss: 0.2577 - val_IOU: 0.7423
#
# Epoch 00037: val_loss did not improve from 0.24932
# Epoch 38/75
# 125/125 [==============================] - 34s 269ms/step - loss: 0.1352 - IOU: 0.8648 - val_loss: 0.2766 - val_IOU: 0.7234
#
# Epoch 00038: val_loss did not improve from 0.24932
# Epoch 39/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1321 - IOU: 0.8679 - val_loss: 0.2609 - val_IOU: 0.7391
#
# Epoch 00039: val_loss did not improve from 0.24932
# Epoch 40/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1324 - IOU: 0.8676 - val_loss: 0.2742 - val_IOU: 0.7258
#
# Epoch 00040: val_loss did not improve from 0.24932
# Epoch 41/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1326 - IOU: 0.8674 - val_loss: 0.2516 - val_IOU: 0.7484
#
# Epoch 00041: val_loss did not improve from 0.24932
# Epoch 42/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1345 - IOU: 0.8655 - val_loss: 0.2382 - val_IOU: 0.7618
#
# Epoch 00042: val_loss improved from 0.24932 to 0.23819, saving model to ./best/unet_weights.h5
# Epoch 43/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1339 - IOU: 0.8661 - val_loss: 0.2625 - val_IOU: 0.7375
#
# Epoch 00043: val_loss did not improve from 0.23819
# Epoch 44/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1304 - IOU: 0.8696 - val_loss: 0.2451 - val_IOU: 0.7549
#
# Epoch 00044: val_loss did not improve from 0.23819
# Epoch 45/75
# 125/125 [==============================] - 34s 269ms/step - loss: 0.1339 - IOU: 0.8661 - val_loss: 0.2602 - val_IOU: 0.7398
#
# Epoch 00045: val_loss did not improve from 0.23819
# Epoch 46/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1343 - IOU: 0.8657 - val_loss: 0.2575 - val_IOU: 0.7425
#
# Epoch 00046: val_loss did not improve from 0.23819
# Epoch 47/75
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1321 - IOU: 0.8679 - val_loss: 0.2660 - val_IOU: 0.7340
#
# Epoch 00047: val_loss did not improve from 0.23819
# Epoch 48/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1306 - IOU: 0.8694 - val_loss: 0.2852 - val_IOU: 0.7148
#
# Epoch 00048: val_loss did not improve from 0.23819
# Epoch 49/75
# 125/125 [==============================] - 34s 274ms/step - loss: 0.1312 - IOU: 0.8688 - val_loss: 0.2733 - val_IOU: 0.7267
#
# Epoch 00049: val_loss did not improve from 0.23819
# Epoch 50/75
# 125/125 [==============================] - 34s 270ms/step - loss: 0.1305 - IOU: 0.8695 - val_loss: 0.2494 - val_IOU: 0.7506
#
# Epoch 00050: val_loss did not improve from 0.23819
# Epoch 51/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1309 - IOU: 0.8691 - val_loss: 0.2664 - val_IOU: 0.7336
#
# Epoch 00051: val_loss did not improve from 0.23819
# Epoch 52/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1276 - IOU: 0.8724 - val_loss: 0.2861 - val_IOU: 0.7139
#
# Epoch 00052: val_loss did not improve from 0.23819
# Epoch 53/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1276 - IOU: 0.8724 - val_loss: 0.2601 - val_IOU: 0.7399
#
# Epoch 00053: val_loss did not improve from 0.23819
# Epoch 54/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1307 - IOU: 0.8693 - val_loss: 0.2970 - val_IOU: 0.7030
#
# Epoch 00054: val_loss did not improve from 0.23819
# Epoch 55/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1303 - IOU: 0.8697 - val_loss: 0.2641 - val_IOU: 0.7359
#
# Epoch 00055: val_loss did not improve from 0.23819
# Epoch 56/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1276 - IOU: 0.8724 - val_loss: 0.2619 - val_IOU: 0.7381
#
# Epoch 00056: val_loss did not improve from 0.23819
# Epoch 57/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1304 - IOU: 0.8696 - val_loss: 0.2800 - val_IOU: 0.7200
#
# Epoch 00057: val_loss did not improve from 0.23819
# Epoch 58/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1290 - IOU: 0.8710 - val_loss: 0.2566 - val_IOU: 0.7434
#
# Epoch 00058: val_loss did not improve from 0.23819
# Epoch 59/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1247 - IOU: 0.8753 - val_loss: 0.2436 - val_IOU: 0.7564
#
# Epoch 00059: val_loss did not improve from 0.23819
# Epoch 60/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1257 - IOU: 0.8743 - val_loss: 0.2664 - val_IOU: 0.7336
#
# Epoch 00060: val_loss did not improve from 0.23819
# Epoch 61/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1231 - IOU: 0.8769 - val_loss: 0.2455 - val_IOU: 0.7545
#
# Epoch 00061: val_loss did not improve from 0.23819
# Epoch 62/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1271 - IOU: 0.8729 - val_loss: 0.2657 - val_IOU: 0.7343
#
# Epoch 00062: val_loss did not improve from 0.23819
# Epoch 63/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1234 - IOU: 0.8766 - val_loss: 0.2531 - val_IOU: 0.7469
#
# Epoch 00063: val_loss did not improve from 0.23819
# Epoch 64/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1253 - IOU: 0.8747 - val_loss: 0.2571 - val_IOU: 0.7429
#
# Epoch 00064: val_loss did not improve from 0.23819
# Epoch 65/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1272 - IOU: 0.8728 - val_loss: 0.2561 - val_IOU: 0.7439
#
# Epoch 00065: val_loss did not improve from 0.23819
# Epoch 66/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1227 - IOU: 0.8773 - val_loss: 0.2443 - val_IOU: 0.7557
#
# Epoch 00066: val_loss did not improve from 0.23819
# Epoch 67/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1248 - IOU: 0.8752 - val_loss: 0.2537 - val_IOU: 0.7463
#
# Epoch 00067: val_loss did not improve from 0.23819
# Epoch 68/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1259 - IOU: 0.8741 - val_loss: 0.2631 - val_IOU: 0.7369
#
# Epoch 00068: val_loss did not improve from 0.23819
# Epoch 69/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1256 - IOU: 0.8744 - val_loss: 0.2596 - val_IOU: 0.7404
#
# Epoch 00069: val_loss did not improve from 0.23819
# Epoch 70/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1222 - IOU: 0.8778 - val_loss: 0.2596 - val_IOU: 0.7404
#
# Epoch 00070: val_loss did not improve from 0.23819
# Epoch 71/75
# 125/125 [==============================] - 34s 271ms/step - loss: 0.1249 - IOU: 0.8751 - val_loss: 0.2591 - val_IOU: 0.7409
#
# Epoch 00071: val_loss did not improve from 0.23819
# Epoch 72/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1217 - IOU: 0.8783 - val_loss: 0.2422 - val_IOU: 0.7578
#
# Epoch 00072: val_loss did not improve from 0.23819
# Epoch 73/75
# 125/125 [==============================] - 34s 273ms/step - loss: 0.1244 - IOU: 0.8756 - val_loss: 0.2707 - val_IOU: 0.7293
#
# Epoch 00073: val_loss did not improve from 0.23819
# Epoch 74/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1250 - IOU: 0.8750 - val_loss: 0.2672 - val_IOU: 0.7328
#
# Epoch 00074: val_loss did not improve from 0.23819
# Epoch 75/75
# 125/125 [==============================] - 34s 272ms/step - loss: 0.1231 - IOU: 0.8769 - val_loss: 0.2557 - val_IOU: 0.7443
#
# Epoch 00075: val_loss did not improve from 0.23819

# %%
visualize_loss_and_metric([history1])

# %%
out = model.predict(X_test * (1./255), batch_size=16)
out.shape
# Out:
# (600, 192, 256, 1)

# %%
iou = IOU(Y_test, out)
print(iou)
# Out:
# tf.Tensor(0.7631006, shape=(), dtype=float32)

# %%
axes_num = 0
num_images = 10
index_list = np.random.choice(600, num_images)
for i in range(num_images):
    plt.figure(figsize=(15,25))
    plt.subplot(num_images, 3, axes_num+1)
    plt.imshow(X_test[index_list[i]])
    plt.title('Original Image')

    plt.subplot(num_images, 3, axes_num+2)
    plt.imshow(np.squeeze(out[index_list[i]]), cmap='gray')
    plt.title('Predicted Segmentation')
    
    plt.subplot(num_images, 3, axes_num+3)
    plt.imshow(np.squeeze(Y_test[index_list[i]]), cmap='gray')
    plt.title('GroundTruth Segmentation')
    axes_num += 3

plt.show()
